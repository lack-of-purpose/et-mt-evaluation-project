# %%
import pandas as pd
from pathlib import Path
import os
cwd = Path.cwd()

fix1 = pd.read_csv(f'{cwd}/participant1/fixations_stats.csv')
jump1 = pd.read_csv(f'{cwd}/participant1/saccades_stats.csv')

fix2 = pd.read_csv(f'{cwd}/participant2/fixations_stats.csv')
jump2 = pd.read_csv(f'{cwd}/participant2/saccades_stats.csv')

fix3 = pd.read_csv(f'{cwd}/participant3/fixations_stats.csv')
jump3 = pd.read_csv(f'{cwd}/participant3/saccades_stats.csv')

fix4 = pd.read_csv(f'{cwd}/participant4/fixations_stats.csv')
jump4 = pd.read_csv(f'{cwd}/participant4/saccades_stats.csv')

fix5 = pd.read_csv(f'{cwd}/participant5/fixations_stats.csv')
jump5 = pd.read_csv(f'{cwd}/participant5/saccades_stats.csv')

fix6 = pd.read_csv(f'{cwd}/participant6/fixations_stats.csv')
jump6 = pd.read_csv(f'{cwd}/participant6/saccades_stats.csv')

fix7 = pd.read_csv(f'{cwd}/participant7/fixations_stats.csv')
jump7 = pd.read_csv(f'{cwd}/participant7/saccades_stats.csv')

fix8 = pd.read_csv(f'{cwd}/participant8/fixations_stats.csv')
jump8 = pd.read_csv(f'{cwd}/participant8/saccades_stats.csv')

# %%
fixes1 = fix1.groupby(['set']).sum()
fixes2 = fix2.groupby(['set']).sum()
fixes3 = fix3.groupby(['set']).sum()
fixes4 = fix4.groupby(['set']).sum()
fixes5 = fix5.groupby(['set']).sum()
fixes6 = fix6.groupby(['set']).sum()
fixes7 = fix7.groupby(['set']).sum()
fixes8 = fix8.groupby(['set']).sum()

# %%
jumps1 = jump1.groupby(['set']).sum()
jumps2 = jump2.groupby(['set']).sum()
jumps3 = jump3.groupby(['set']).sum()
jumps4 = jump4.groupby(['set']).sum()
jumps5 = jump5.groupby(['set']).sum()
jumps6 = jump6.groupby(['set']).sum()
jumps7 = jump7.groupby(['set']).sum()
jumps8 = jump8.groupby(['set']).sum()

# %%
for fix, jump in zip([fix1,fix2,fix3,fix4,fix5,fix6,fix7,fix8], [jump1,jump2,jump3,jump4,jump5,jump6,jump7,jump8]):
    fix['set'] = fix['set'].astype('str')
    fix['screen'] = fix['screen'].astype('str')
    jump['set'] = jump['set'].astype('str')
    jump['screen'] = jump['screen'].astype('str')

# %%
for fix, jump in zip([fix1,fix2,fix3,fix4,fix5,fix6,fix7,fix8], [jump1,jump2,jump3,jump4,jump5,jump6,jump7,jump8]):
    fix['set_screen'] = (fix['set'] + '_' + fix['screen'])
    jump['set_screen'] = (jump['set'] + '_' + jump['screen'])

# %%
fix_d1 = fix1[['set_screen', 'num_of_fixes']]
fix_d1 = dict(zip(fix_d1.set_screen, fix_d1.num_of_fixes))

fix_d2 = fix2[['set_screen', 'num_of_fixes']]
fix_d2 = dict(zip(fix_d2.set_screen, fix_d2.num_of_fixes))

fix_d3 = fix3[['set_screen', 'num_of_fixes']]
fix_d3 = dict(zip(fix_d3.set_screen, fix_d3.num_of_fixes))

fix_d4 = fix4[['set_screen', 'num_of_fixes']]
fix_d4 = dict(zip(fix_d4.set_screen, fix_d4.num_of_fixes))

fix_d5 = fix5[['set_screen', 'num_of_fixes']]
fix_d5 = dict(zip(fix_d5.set_screen, fix_d5.num_of_fixes))

fix_d6 = fix6[['set_screen', 'num_of_fixes']]
fix_d6 = dict(zip(fix_d6.set_screen, fix_d6.num_of_fixes))

fix_d7 = fix7[['set_screen', 'num_of_fixes']]
fix_d7 = dict(zip(fix_d7.set_screen, fix_d7.num_of_fixes))

fix_d8 = fix8[['set_screen', 'num_of_fixes']]
fix_d8 = dict(zip(fix_d8.set_screen, fix_d8.num_of_fixes))

# %%
fix_d1_inter = fix1[['set_screen', 'intersections']]
fix_d1_inter = dict(zip(fix_d1_inter.set_screen, fix_d1_inter.intersections))

fix_d2_inter = fix2[['set_screen', 'intersections']]
fix_d2_inter = dict(zip(fix_d2_inter.set_screen, fix_d2_inter.intersections))

fix_d3_inter = fix3[['set_screen', 'intersections']]
fix_d3_inter = dict(zip(fix_d3_inter.set_screen, fix_d3_inter.intersections))

fix_d4_inter = fix4[['set_screen', 'intersections']]
fix_d4_inter = dict(zip(fix_d4_inter.set_screen, fix_d4_inter.intersections))

fix_d5_inter = fix5[['set_screen', 'intersections']]
fix_d5_inter = dict(zip(fix_d5_inter.set_screen, fix_d5_inter.intersections))

fix_d6_inter = fix6[['set_screen', 'intersections']]
fix_d6_inter = dict(zip(fix_d6_inter.set_screen, fix_d6_inter.intersections))

fix_d7_inter = fix7[['set_screen', 'intersections']]
fix_d7_inter = dict(zip(fix_d7_inter.set_screen, fix_d7_inter.intersections))

fix_d8_inter = fix8[['set_screen', 'intersections']]
fix_d8_inter = dict(zip(fix_d8_inter.set_screen, fix_d8_inter.intersections))

# %%
jump_d1 = jump1[['set_screen', 'num_of_jumps']]
jump_d1 = dict(zip(jump1.set_screen, jump1.num_of_jumps))

jump_d2 = jump2[['set_screen', 'num_of_jumps']]
jump_d2 = dict(zip(jump2.set_screen, jump2.num_of_jumps))

jump_d3 = jump3[['set_screen', 'num_of_jumps']]
jump_d3 = dict(zip(jump3.set_screen, jump3.num_of_jumps))

jump_d4 = jump4[['set_screen', 'num_of_jumps']]
jump_d4 = dict(zip(jump4.set_screen, jump4.num_of_jumps))

jump_d5 = jump5[['set_screen', 'num_of_jumps']]
jump_d5 = dict(zip(jump5.set_screen, jump5.num_of_jumps))

jump_d6 = jump6[['set_screen', 'num_of_jumps']]
jump_d6 = dict(zip(jump6.set_screen, jump6.num_of_jumps))

jump_d7 = jump7[['set_screen', 'num_of_jumps']]
jump_d7 = dict(zip(jump7.set_screen, jump7.num_of_jumps))

jump_d8 = jump8[['set_screen', 'num_of_jumps']]
jump_d8 = dict(zip(jump8.set_screen, jump8.num_of_jumps))

# %%
jump_d1_inter = jump1[['set_screen', 'intersections']]
jump_d1_inter = dict(zip(jump1.set_screen, jump1.intersections))

jump_d2_inter = jump2[['set_screen', 'intersections']]
jump_d2_inter = dict(zip(jump2.set_screen, jump2.intersections))

jump_d3_inter = jump3[['set_screen', 'intersections']]
jump_d3_inter = dict(zip(jump3.set_screen, jump3.intersections))

jump_d4_inter = jump4[['set_screen', 'intersections']]
jump_d4_inter = dict(zip(jump4.set_screen, jump4.intersections))

jump_d5_inter = jump5[['set_screen', 'intersections']]
jump_d5_inter = dict(zip(jump5.set_screen, jump5.intersections))

jump_d6_inter = jump6[['set_screen', 'intersections']]
jump_d6_inter = dict(zip(jump6.set_screen, jump6.intersections))

jump_d7_inter = jump7[['set_screen', 'intersections']]
jump_d7_inter = dict(zip(jump7.set_screen, jump7.intersections))

jump_d8_inter = jump8[['set_screen', 'intersections']]
jump_d8_inter = dict(zip(jump8.set_screen, jump8.intersections))

# %%
import json

f1 = open('participant1/problematic_words.json')
words1 = json.load(f1)

f2 = open('participant2/problematic_words.json')
words2 = json.load(f2)

f3 = open('participant3/problematic_words.json')
words3 = json.load(f3)

f4 = open('participant4/problematic_words.json')
words4 = json.load(f4)

f5 = open('participant5/problematic_words.json')
words5 = json.load(f5)

f6 = open('participant6/problematic_words.json')
words6 = json.load(f6)

f7 = open('participant7/problematic_words.json')
words7 = json.load(f7)

f8 = open('participant8/problematic_words.json')
words8 = json.load(f8)

# %%
num_of_words1 = {}
num_of_words2 = {}
num_of_words3 = {}
num_of_words4 = {}
num_of_words5 = {}
num_of_words6 = {}
num_of_words7 = {}
num_of_words8 = {}
for words, num_of_words in zip([words1, words2, words3, words4, words5, words6, words7, words8],
                               [num_of_words1,num_of_words2,num_of_words3,num_of_words4,num_of_words5,num_of_words6,num_of_words7,num_of_words8]):
    for sett in words.keys():
        for screen in words[sett].keys():
            k = f'{sett}_{screen}'
            num_of_words[k] = len(words[sett][screen])

# %%
len(num_of_words8) == len(jump_d8)
# Out:
# True

# %%
len(num_of_words8) == len(fix_d8)
# Out:
# True

# %%
{k:v for k,v in num_of_words3.items() if k not in fix_d3}
# Out:
# {'3_8': 1}

# %%
len(fix_d3)
# Out:
# 86

# %%
del num_of_words3['3_8']

# %%
! pip install scipy
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
problem_words = []
problem_words.extend(list(num_of_words1.values()))
problem_words.extend(list(num_of_words2.values()))
problem_words.extend(list(num_of_words3.values())) 
problem_words.extend(list(num_of_words4.values())) 
problem_words.extend(list(num_of_words5.values())) 
problem_words.extend(list(num_of_words6.values())) 
problem_words.extend(list(num_of_words7.values()))
problem_words.extend(list(num_of_words8.values()))

# %%
saccades = []
saccades.extend(list(jump_d1.values()))
saccades.extend(list(jump_d2.values()))
saccades.extend(list(jump_d3.values())) 
saccades.extend(list(jump_d4.values())) 
saccades.extend(list(jump_d5.values())) 
saccades.extend(list(jump_d6.values())) 
saccades.extend(list(jump_d7.values())) 
saccades.extend(list(jump_d8.values()))

# %%
saccades_inter = []
saccades_inter.extend(list(jump_d1_inter.values()))
saccades_inter.extend(list(jump_d2_inter.values()))
saccades_inter.extend(list(jump_d3_inter.values())) 
saccades_inter.extend(list(jump_d4_inter.values())) 
saccades_inter.extend(list(jump_d5_inter.values())) 
saccades_inter.extend(list(jump_d6_inter.values())) 
saccades_inter.extend(list(jump_d7_inter.values())) 
saccades_inter.extend(list(jump_d8_inter.values()))

# %%
fixes = []
fixes.extend(list(fix_d1.values()))
fixes.extend(list(fix_d2.values()))
fixes.extend(list(fix_d3.values())) 
fixes.extend(list(fix_d4.values())) 
fixes.extend(list(fix_d5.values())) 
fixes.extend(list(fix_d6.values())) 
fixes.extend(list(fix_d7.values())) 
fixes.extend(list(fix_d8.values()))

# %%
saccades_inter
# Out:
# [64,
#  120,
#  23,
#  125,
#  190,
#  0,
#  159,
#  55,
#  161,
#  23,
#  53,
#  261,
#  74,
#  77,
#  254,
#  16,
#  32,
#  92,
#  178,
#  144,
#  46,
#  36,
#  145,
#  23,
#  114,
#  24,
#  29,
#  43,
#  194,
#  47,
#  37,
#  59,
#  41,
#  114,
#  127,
#  100,
#  684,
#  268,
#  65,
#  51,
#  193,
#  43,
#  83,
#  142,
#  99,
#  69,
#  78,
#  11,
#  242,
#  161,
#  112,
#  170,
#  128,
#  35,
#  43,
#  137,
#  335,
#  46,
#  220,
#  44,
#  65,
#  17,
#  62,
#  145,
#  33,
#  65,
#  209,
#  195,
#  137,
#  178,
#  4,
#  11,
#  24,
#  74,
#  41,
#  112,
#  29,
#  166,
#  39,
#  132,
#  54,
#  64,
#  45,
#  324,
#  47,
#  92,
#  83,
#  7,
#  17,
#  110,
#  87,
#  0,
#  76,
#  34,
#  54,
#  71,
#  138,
#  59,
#  90,
#  50,
#  30,
#  82,
#  70,
#  37,
#  53,
#  20,
#  89,
#  129,
#  113,
#  73,
#  82,
#  106,
#  30,
#  13,
#  156,
#  72,
#  22,
#  95,
#  29,
#  24,
#  118,
#  97,
#  55,
#  150,
#  115,
#  178,
#  119,
#  219,
#  441,
#  61,
#  30,
#  133,
#  154,
#  14,
#  65,
#  39,
# ...

# %%
fixes_inter = []
fixes_inter.extend(list(fix_d1_inter.values()))
fixes_inter.extend(list(fix_d2_inter.values()))
fixes_inter.extend(list(fix_d3_inter.values())) 
fixes_inter.extend(list(fix_d4_inter.values())) 
fixes_inter.extend(list(fix_d5_inter.values())) 
fixes_inter.extend(list(fix_d6_inter.values())) 
fixes_inter.extend(list(fix_d7_inter.values())) 
fixes_inter.extend(list(fix_d8_inter.values()))

# %%
fixes_inter
# Out:
# [7,
#  52,
#  2,
#  67,
#  23,
#  0,
#  59,
#  16,
#  36,
#  0,
#  10,
#  62,
#  22,
#  40,
#  88,
#  2,
#  14,
#  23,
#  85,
#  55,
#  19,
#  9,
#  55,
#  9,
#  38,
#  4,
#  10,
#  3,
#  110,
#  19,
#  13,
#  25,
#  12,
#  55,
#  46,
#  15,
#  194,
#  66,
#  11,
#  25,
#  70,
#  25,
#  12,
#  85,
#  26,
#  14,
#  34,
#  0,
#  89,
#  67,
#  33,
#  34,
#  0,
#  15,
#  17,
#  69,
#  97,
#  5,
#  76,
#  31,
#  26,
#  0,
#  23,
#  55,
#  8,
#  3,
#  90,
#  52,
#  73,
#  49,
#  0,
#  0,
#  7,
#  53,
#  6,
#  34,
#  27,
#  67,
#  6,
#  45,
#  19,
#  20,
#  17,
#  110,
#  19,
#  27,
#  29,
#  2,
#  1,
#  41,
#  37,
#  0,
#  15,
#  7,
#  34,
#  31,
#  51,
#  32,
#  15,
#  21,
#  21,
#  29,
#  19,
#  23,
#  22,
#  8,
#  60,
#  43,
#  35,
#  27,
#  23,
#  37,
#  5,
#  9,
#  59,
#  27,
#  3,
#  25,
#  7,
#  9,
#  26,
#  23,
#  8,
#  40,
#  45,
#  78,
#  28,
#  58,
#  137,
#  14,
#  13,
#  74,
#  71,
#  3,
#  10,
#  20,
#  35,
#  24,
#  9,
#  11,
#  0,
#  16,
#  29,
#  57,
#  84,
#  74,
#  20,
# ...

# %%
import pandas as pd
part1 = pd.read_csv('data-participant1.csv')
part2 = pd.read_csv('data-participant2.csv')
part3 = pd.read_csv('data-participant3.csv')
part4 = pd.read_csv('data-participant4.csv')
part5 = pd.read_csv('data-participant5.csv')
part6 = pd.read_csv('data-participant6.csv')
part7 = pd.read_csv('data-participant7.csv')
part8 = pd.read_csv('data-participant8.csv')
full_data = pd.concat([part1, part2,part3, part4, part5, part6, part7, part8], ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16728\1310253175.py in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 part1 = pd.read_csv('data-participant1.csv')
#       3 part2 = pd.read_csv('data-participant2.csv')
#       4 part3 = pd.read_csv('data-participant3.csv')
#       5 part4 = pd.read_csv('data-participant4.csv')
#
# c:\Users\lack_\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# c:\Users\lack_\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
# ...

# %%
import scipy.stats as stats

coeff = stats.pearsonr(saccades, problem_words)
coeff
# Out:
# PearsonRResult(statistic=0.0984337737388147, pvalue=0.00862785703787529)

# %%
coeff = stats.pearsonr(fixes_inter, fixes)
coeff
# Out:
# PearsonRResult(statistic=0.4307299113850966, pvalue=1.758600002771961e-33)

# %%
import math 

def fixation_pearson()
    n = len(num_of_words)
    x_mean = sum(fix_d.values())/n
    y_mean = sum(num_of_words.values())/n
    nominator = 0
    for k in num_of_words.keys():
        if k in fix_d.keys():
            nominator += fix_d[k]*num_of_words[k]

    nominator -= n*x_mean*y_mean

    denominator_left = 0
    denominator_right = 0
    for k in num_of_words.keys():
        if k in fix_d.keys():
            denominator_left += fix_d[k]*fix_d[k]
            denominator_right += num_of_words[k]*num_of_words[k]

    denominator_left -= n*x_mean*x_mean
    denominator_right -= n*y_mean*y_mean
    denominator = math.sqrt(denominator_left)*math.sqrt(denominator_right)


    fix_pearson_corr_coeff = nominator/denominator
    
    return fix_pearson_corr_coeff
print(f'Pearson correlation coefficient for number of fixes and problematic words {fix_pearson_corr_coeff}')
# Out:
# Pearson correlation coefficient for number of fixes and problematic words 0.19658012119796017

# %%
n = len(num_of_words)
x_mean = sum(jump_d.values())/n
y_mean = sum(num_of_words.values())/n
nominator = 0
for k in num_of_words.keys():
    if k in jump_d.keys():
        nominator += jump_d[k]*num_of_words[k]

nominator -= n*x_mean*y_mean

denominator_left = 0
denominator_right = 0
for k in num_of_words.keys():
    if k in jump_d.keys():
        denominator_left += jump_d[k]*jump_d[k]
        denominator_right += num_of_words[k]*num_of_words[k]

denominator_left -= n*x_mean*x_mean
denominator_right -= n*y_mean*y_mean
denominator = math.sqrt(denominator_left)*math.sqrt(denominator_right)


jump_pearson_corr_coeff = nominator/denominator
print(f'Pearson correlation coefficient for number of jumps and problematic words {jump_pearson_corr_coeff}')
# Out:
# Pearson correlation coefficient for number of jumps and problematic words 0.19787697080007502

# %%
test_statistic = jump_pearson_corr_coeff*math.sqrt(n-2)/math.sqrt(1-jump_pearson_corr_coeff*jump_pearson_corr_coeff)
print(f'T-value for jump {test_statistic}')
# Out:
# T-value for jump 1.8936948101817357

# %%
test_statistic = fix_pearson_corr_coeff*math.sqrt(n-2)/math.sqrt(1-fix_pearson_corr_coeff*fix_pearson_corr_coeff)
print(f'T-value for fix {test_statistic}')
# Out:
# T-value for fix 1.8807832837964156

# %%
# fixes, saccades, fixes_inter, saccades_inter, problem_words

# %%
import seaborn
import matplotlib.pyplot as plt

seaborn.displot(problem_words, kind="kde")

# %%
import seaborn
import matplotlib.pyplot as plt
 
seaborn.set_theme(style='whitegrid')
seaborn.color_palette()
fig, ax = plt.subplots(figsize=(10,7))
seaborn.scatterplot(x=list(fix_d1.values()),
                    y=list(num_of_words1.values()))
seaborn.scatterplot(x=list(fix_d2.values()),
                    y=list(num_of_words2.values()))
seaborn.scatterplot(x=list(fix_d3.values()),
                    y=list(num_of_words3.values()))
seaborn.scatterplot(x=list(fix_d4.values()),
                    y=list(num_of_words4.values()))
seaborn.scatterplot(x=list(fix_d5.values()),
                    y=list(num_of_words5.values()))
seaborn.scatterplot(x=list(fix_d6.values()),
                    y=list(num_of_words6.values()))
seaborn.scatterplot(x=list(fix_d7.values()),
                    y=list(num_of_words7.values()))
seaborn.scatterplot(x=list(fix_d8.values()),
                    y=list(num_of_words8.values()))
ax.set(xlabel='Number of fixations', ylabel='Number of problematic words')
# Out:
# [Text(0.5, 0, 'Number of fixations'),
#  Text(0, 0.5, 'Number of problematic words')]

# %%
fig, ax = plt.subplots(figsize=(10,7))
seaborn.scatterplot(x=list(jump_d1.values()),
                    y=list(num_of_words1.values()))
seaborn.scatterplot(x=list(jump_d2.values()),
                    y=list(num_of_words2.values()))
seaborn.scatterplot(x=list(jump_d3.values()),
                    y=list(num_of_words3.values()))
seaborn.scatterplot(x=list(jump_d4.values()),
                    y=list(num_of_words4.values()))
seaborn.scatterplot(x=list(jump_d5.values()),
                    y=list(num_of_words5.values()))
seaborn.scatterplot(x=list(jump_d6.values()),
                    y=list(num_of_words6.values()))
seaborn.scatterplot(x=list(jump_d7.values()),
                    y=list(num_of_words7.values()))
seaborn.scatterplot(x=list(jump_d8.values()),
                    y=list(num_of_words8.values()))
ax.set(xlabel='Number of saccades', ylabel='Number of problematic words')
# Out:
# [Text(0.5, 0, 'Number of saccades'),
#  Text(0, 0.5, 'Number of problematic words')]

# %%
import seaborn
import matplotlib.pyplot as plt
 
seaborn.set_theme(style='whitegrid')
seaborn.color_palette()
fig, ax = plt.subplots(figsize=(10,7))
seaborn.scatterplot(x=saccades_inter,
                    y=problem_words)
ax.set(xlabel='Number of saccades', ylabel='Number of problematic words')
# Out:
# [Text(0.5, 0, 'Number of saccades'),
#  Text(0, 0.5, 'Number of problematic words')]

# %%
dict = {'fixes': fixes, 'fixes_inter': fixes_inter, 'saccades': saccades, 'saccades_inter': saccades_inter, 'problem_words': problem_words} 
   
overall_stat = pd.DataFrame(dict)
overall_stat
# Out:
#      fixes  fixes_inter  saccades  saccades_inter  problem_words
# 0      268            7       273              64              5
# 1      684           52       706             120              2
# 2      296            2       302              23              3
# 3      706           67       731             125              3
# 4      304           23       314             190              4
# ..     ...          ...       ...             ...            ...
# 706   1077           11      1110              47              3
# 707    871           16       897              45              3
# 708    871            4       886              42              3
# 709    454            0       471               4              1
# 710   1028           47      1055             181              9
#
# [711 rows x 5 columns]

# %%
overall_stat['fix_proportion'] = overall_stat['fixes_inter'] / overall_stat['fixes']
overall_stat['saccade_proportion'] = overall_stat['saccades_inter'] / overall_stat['saccades']
overall_stat
# Out:
#      fixes  fixes_inter  saccades  saccades_inter  problem_words  \
# 0      268            7       273              64              5
# 1      684           52       706             120              2
# 2      296            2       302              23              3
# 3      706           67       731             125              3
# 4      304           23       314             190              4
# ..     ...          ...       ...             ...            ...
# 706   1077           11      1110              47              3
# 707    871           16       897              45              3
# 708    871            4       886              42              3
# 709    454            0       471               4              1
# 710   1028           47      1055             181              9
#
#      fix_proportion  saccade_proportion
# 0          0.026119            0.234432
# 1          0.076023            0.169972
# 2          0.006757            0.076159
# ...

# %%
fig, ax = plt.subplots(figsize=(10,7))
seaborn.scatterplot(x=overall_stat['saccade_proportion'],
                    y=problem_words, color='g')
ax.set(xlabel='Sacccades proportion', ylabel='Number of problematic words')
# Out:
# [Text(0.5, 0, 'Sacccades proportion'),
#  Text(0, 0.5, 'Number of problematic words')]

# %%
fig, ax = plt.subplots(figsize=(10,7))
seaborn.scatterplot(x=overall_stat['fix_proportion'],
                    y=problem_words, color='b')
ax.set(xlabel='Fixations proportion', ylabel='Number of problematic words')
# Out:
# [Text(0.5, 0, 'Fixations proportion'),
#  Text(0, 0.5, 'Number of problematic words')]

# %%
coeff = stats.pearsonr(overall_stat['saccade_proportion'], problem_words)
coeff
# Out:
# PearsonRResult(statistic=0.43982404562542476, pvalue=5.399909109137013e-35)

# %%
coeff = stats.pearsonr(overall_stat['fix_proportion'], problem_words)
coeff
# Out:
# PearsonRResult(statistic=0.3033262830955918, pvalue=1.345847275577482e-16)
